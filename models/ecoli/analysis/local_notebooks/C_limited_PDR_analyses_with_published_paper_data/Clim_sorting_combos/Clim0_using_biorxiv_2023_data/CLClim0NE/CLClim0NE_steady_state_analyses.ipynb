# %% [markdown]
# # CLClim0NE: Visualize the results of the CLClim0NE protein outputs compared to those in the original model

# %%
import pickle
import os
import pandas as pd
from matplotlib import pyplot as plt
os.chdir(os.path.expanduser('~/wcEcoli/out/'))
# noinspection PyUnresolvedReferences
import numpy as np
import plotly.graph_objects as go
from models.ecoli.analysis import cohortAnalysisPlot
from wholecell.analysis.analysis_tools import (exportFigure,
	read_bulk_molecule_counts, read_stacked_bulk_molecules, read_stacked_columns)
from wholecell.io.tablereader import TableReader
from sklearn.metrics import r2_score

# %% [markdown]
# # Load in the simulation data for the original model (CLNE) and the CLClim0NE model

# %%
# CLNE # todo explain how I got this data from running a sim and runing the cohort save data file 

VS_log_CLNE = pd.read_csv('PDR_CLNE/wildtype_000000/cohort_saved_protein_count_data/validation_data/log_data/Log10_Schmidt_Comparison_startGen_2.csv')
VW_log_CLNE = pd.read_csv('PDR_CLNE/wildtype_000000/cohort_saved_protein_count_data/validation_data/log_data/Log10_Wisniewski_Comparison_startGen_2.csv')

# CLClimNE
VS_log_CLClimNE = pd.read_csv('CLClimNE/wildtype_000000/cohort_saved_protein_count_data/validation_data/log_data/Log10_Schmidt_Comparison_startGen_2.csv')
VW_log_CLClimNE = pd.read_csv('CLClimNE/wildtype_000000/cohort_saved_protein_count_data/validation_data/log_data/Log10_Wisniewski_Comparison_startGen_2.csv')

# %%
# specifiy the current sequence being used: 
current_sequence = 'CLClim0NE'
Clim_name = 'Clim0'

# %% [markdown]
# # Schmidt Validation Data Comparisons

# %% [markdown]
# Plot #1: Compare the Schmidt Validation Protein Counts for the CLNE and CLClim0NE models

# %%
# Create scatter plot of Schmidt Validation Protein Counts vs CLNE and CLClimNE Counts
def add_scatter_and_trendline(fig, df, name):
    x = df["Log10 Validation Schmidt Counts"]
    y = df["Log10 Simulated Schmidt Counts"]
    hovertext = df["Monomer ID"]

    # Add scatter trace
    fig.add_trace(go.Scatter(x=x, y=y, hovertext=hovertext, mode='markers', name=name))

    # Compute trendline
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)
    trendline_y = p(x)

    # Add trendline trace
    fig.add_trace(go.Scatter(x=x, y=trendline_y, mode='lines', name=f'{name} Trendline: {p}'))

# Create figure
fig = go.Figure()

# Add scatter plots and trendlines for each dataset
add_scatter_and_trendline(fig, VS_log_CLNE, 'CLNE vs Schmidt')
add_scatter_and_trendline(fig, VS_log_CLClimNE, (current_sequence +' vs Schmidt'))

# Update layout
fig.update_traces(marker_size=3)
fig.update_layout(
    title=f"Schmidt Validation Protein Counts vs CLNE and {current_sequence}",
    xaxis_title="log10(Schmidt Validation Protein Counts)",
    yaxis_title=f"log10(CLNE, {current_sequence})",
    autosize=False,
    width=900,
    height=600
)

# add a y=x line
fig.add_trace(go.Scatter(x=[0, 6], y=[0, 6], mode="lines",
        line=go.scatter.Line(color="black", dash="dash"), opacity=0.2,
        name="y=x"));
# Show figure
fig.show()
# Out:
# <div>                            <div id="f96ba7ed-6549-483d-8b69-6ff61100d780" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f96ba7ed-6549-483d-8b69-6ff61100d780")) {                    Plotly.newPlot(                        "f96ba7ed-6549-483d-8b69-6ff61100d780",                        [{"hovertext":["EG10339-MONOMER[c]","EG11008-MONOMER[p]","G7416-MONOMER[c]","EG10923-MONOMER[c]","YLIA-MONOMER[i]","GLNH-MONOMER[p]","PANTEPADENYLYLTRAN-MONOMER[c]","CYSN-MONOMER[c]","EG11007-MONOMER[i]","G7875-MONOMER[i]","PD00339[c]","G6990-MONOMER[o]","EG12861-MONOMER[c]","G6383-MONOMER[c]","G7612-MONOMER[i]","XYLG-MONOMER[m]","EG12702-MONOMER[c]","THRESYN-MONOMER[c]","G6194-MONOMER[p]","G7258-MONOMER[i]","EG10864-MONOMER[c]","SHIA-MONOMER[i]","EG10242-MONOMER[c]","EG10015-MONOMER[i]","ACNEULY-MONOMER[c]","PEPSYNTH-MONOMER[c]","7-ALPHA-HYDROXYSTEROID-DEH-MONOMER[c]","SUCCCOASYN-BETA[c]","G6451-MONOMER[i]","PD00196[c]","DIOHBUTANONEPSYN-MONOMER[c]","BASR-MONOMER[c]","EG10748-MONOMER[m]","ATPE-MONOMER[m]","ALDDEHYDROGB-MONOMER[c]","TRE6PHYDRO-MONOMER[c]","G7525-MONOMER[c]","GLYCDEH-MONOMER[c]","YDCT-MONOMER[i]","G7925-MONOMER[c]","EG10915-MONOMER[c]","G6924-MONOMER[c]","EG10977-MONOMER[c]","BARA-MONOMER[i]","BIOTINLIG-MONOMER[c]","NUOA-MONOMER[m]","EG10862-MONOMER[c]","G6560-MONOMER[c]","G6428-MONOMER[c]","G7039-MONOMER[p]","EG11929-MONOMER[c]","G7489-MONOMER[c]","EG12105-MONOMER[c]","DPPF-MONOMER[m]","MONOMER0-4521[c]","G7137-MONOMER[c]","EG11983-MONOMER[c]","FLGH-FLAGELLAR-L-RING[j]","G6905-MONOMER[c]","HISTPHOSTRANS-MONOMER[c]","CYDB-MONOMER[m]","G7758-MONOMER[c]","EG12158-MONOMER[c]","EG11535-MONOMER[c]","VALINE-PYRUVATE-AMINOTRANSFER-MONOMER[c]","EG12851-MONOMER[c]","G6255-MONOMER[i]","YADG-MONOMER[i]","ACRD-MONOMER[i]","NUOK-MONOMER[m]","EG11702-MONOMER[c]","EG10272-MONOMER[i]","G7606-MONOMER[m]","GLYCPDIESTER-CYTO-MONOMER[c]","EG12233-MONOMER[c]","EG12712-MONOMER[c]","EG12193-MONOMER[c]","EG10927-MONOMER[c]","EG12352-MONOMER[c]","XYLULOKIN-MONOMER[c]","AICARTRANSIMPCYCLO-CPLX[c]","B0899-MONOMER[c]","G6243-MONOMER[p]","ALPHACOMP-MONOMER[c]","G7528-MONOMER[i]","MALF-MONOMER[m]","CARBPSYN-LARGE[c]","G7837-MONOMER[c]","CARBOXYL-TRANSFERASE-ALPHA-MONOMER[c]","G7532-MONOMER[c]","G7055-MONOMER[c]","G7580-MONOMER[c]","EG11519-MONOMER[c]","EG11529-MONOMER[i]","EG12188-MONOMER[c]","PITA-MONOMER[i]","EG10914-MONOMER[c]","G7533-MONOMER[m]","G7885-MONOMER[c]","G7420-MONOMER[c]","LIVG-MONOMER[m]","EG12443-MONOMER[c]","EG10087-MONOMER[c]","MANNPISOM-MONOMER[c]","EG11088-MONOMER[c]","ADENYLYLSULFKIN-MONOMER[c]","G6622-MONOMER[i]","PD03938[c]","G6849-MONOMER[c]","EG11916-MONOMER[c]","G7424-MONOMER[i]","G6500-MONOMER[c]","G6644-MONOMER[c]","EG11004-MONOMER[c]","EG11852-MONOMER[c]","EG11413-MONOMER[c]","EG10955-MONOMER[c]","IMP-DEHYDROG-MONOMER[c]","EG11438-MONOMER[c]","KDO-8PSYNTH-MONOMER[c]","FOLC-MONOMER[c]","EG12855-MONOMER[c]","YBAL-MONOMER[i]","EG11494-MONOMER[i]","EG10040-MONOMER[p]","G6527-MONOMER[p]","G7056-MONOMER[m]","RBSA-MONOMER[m]","EG11100-MONOMER[c]","G7184-MONOMER[c]","EG12386-MONOMER[c]","G6757-MONOMER[c]","ARTP-MONOMER[i]","EG11537-MONOMER[c]","EG11110-MONOMER[m]","AMTB-MONOMER[m]","GPT-MONOMER[c]","EG11082-MONOMER[c]","PDXK-MONOMER[c]","MANNPDEHYDROG-MONOMER[c]","EG10204-MONOMER[c]","AROP-MONOMER[i]","EG11288-MONOMER[c]","EG11676-MONOMER[c]","OPPC-MONOMER[i]","POTC-MONOMER[i]","OCTAPRENYL-METHYL-METHOXY-BENZOQ-OH-MON[c]","G6186-MONOMER[c]","G6415-MONOMER[p]","NUOH-MONOMER[m]","EG12387-MONOMER[c]","EG10596-MONOMER[c]","G6244-MONOMER[c]","G6662-MONOMER[c]","UDPNACETYLGLUCOSAMACYLTRANS-MONOMER[c]","BTUE-MONOMER[p]","G6719-MONOMER[c]","EG10122-MONOMER[c]","EG11183-MONOMER[i]","L-GLN-FRUCT-6-P-AMINOTRANS-MONOMER[c]","EG11534-MONOMER[c]","EG11118-MONOMER[c]","B2075-MONOMER[i]","ILES-MONOMER[c]","G7459-M ...

# %% [markdown]
# Plot #2: Compare the Schmidt Validation Protein Counts for the CLNE and CLClim0NE models (but filter values below log10(2))

# %%
# Plot the simulation protein counts against the validation counts, filtering out proteins with counts below log10(2) (these are likely to be subgenerational proteins) 
def add_scatter_and_trendline(fig, df, name):
    x = df["Log10 Validation Schmidt Counts"]
    y = df["Log10 Simulated Schmidt Counts"]
    hovertext = df["Monomer ID"]

    # Add scatter 
    fig.add_trace(go.Scatter(x=x, y=y, hovertext=hovertext, mode='markers', name=name))

    # Compute trendline for data 
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)
    trendline_y = p(x)

    # Add trendline 
    fig.add_trace(go.Scatter(x=x, y=trendline_y, mode='lines', name=f'{name} Trendline: {p}'))

# Create figure
fig = go.Figure()

# filter out any counts below log10(2):
VS_log_CLNE_filtered = VS_log_CLNE[(VS_log_CLNE["Log10 Validation Schmidt Counts"] > 2) & (VS_log_CLNE["Log10 Simulated Schmidt Counts"] > 2)]
VS_log_CLClimNE_filtered = VS_log_CLClimNE[(VS_log_CLClimNE["Log10 Validation Schmidt Counts"] > 2) & (VS_log_CLClimNE["Log10 Simulated Schmidt Counts"] > 2)]

# Add scatter plots and trendlines for each dataset
add_scatter_and_trendline(fig, VS_log_CLNE_filtered, 'CLNE vs Schmidt')
add_scatter_and_trendline(fig, VS_log_CLClimNE_filtered, (current_sequence +' vs Schmidt'))

# Update layout
fig.update_traces(marker_size=3)
fig.update_layout(
    title=f"Schmidt Validation Protein Counts vs CLNE and {current_sequence} (filtered for counts > log10(2))",
    xaxis_title="log10(Schmidt Validation Protein Counts)",
    yaxis_title=f"log10(CLNE, {current_sequence})",
    autosize=False,
    width=900,
    height=600
)

# add a y=x line
fig.add_trace(go.Scatter(x=[2, 6], y=[2, 6], mode="lines",
        line=go.scatter.Line(color="black", dash="dash"), opacity=0.2,
        name="y=x"));
# Show figure
fig.show()
# Out:
# <div>                            <div id="26ca7abb-2e17-4187-b0b7-45a9fdcd75d7" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26ca7abb-2e17-4187-b0b7-45a9fdcd75d7")) {                    Plotly.newPlot(                        "26ca7abb-2e17-4187-b0b7-45a9fdcd75d7",                        [{"hovertext":["EG11008-MONOMER[p]","GLNH-MONOMER[p]","CYSN-MONOMER[c]","EG12861-MONOMER[c]","G7612-MONOMER[i]","THRESYN-MONOMER[c]","G6194-MONOMER[p]","G7258-MONOMER[i]","EG10864-MONOMER[c]","EG10242-MONOMER[c]","EG10015-MONOMER[i]","PEPSYNTH-MONOMER[c]","7-ALPHA-HYDROXYSTEROID-DEH-MONOMER[c]","SUCCCOASYN-BETA[c]","PD00196[c]","DIOHBUTANONEPSYN-MONOMER[c]","ATPE-MONOMER[m]","EG10915-MONOMER[c]","EG10977-MONOMER[c]","NUOA-MONOMER[m]","EG10862-MONOMER[c]","G7039-MONOMER[p]","DPPF-MONOMER[m]","G7137-MONOMER[c]","EG11983-MONOMER[c]","HISTPHOSTRANS-MONOMER[c]","EG12158-MONOMER[c]","VALINE-PYRUVATE-AMINOTRANSFER-MONOMER[c]","EG12851-MONOMER[c]","YADG-MONOMER[i]","NUOK-MONOMER[m]","EG11702-MONOMER[c]","EG10272-MONOMER[i]","G7606-MONOMER[m]","GLYCPDIESTER-CYTO-MONOMER[c]","EG12712-MONOMER[c]","EG12193-MONOMER[c]","EG12352-MONOMER[c]","AICARTRANSIMPCYCLO-CPLX[c]","B0899-MONOMER[c]","ALPHACOMP-MONOMER[c]","G7528-MONOMER[i]","CARBPSYN-LARGE[c]","CARBOXYL-TRANSFERASE-ALPHA-MONOMER[c]","G7532-MONOMER[c]","G7055-MONOMER[c]","EG11519-MONOMER[c]","EG11529-MONOMER[i]","PITA-MONOMER[i]","EG10914-MONOMER[c]","G7885-MONOMER[c]","LIVG-MONOMER[m]","EG12443-MONOMER[c]","MANNPISOM-MONOMER[c]","EG11088-MONOMER[c]","ADENYLYLSULFKIN-MONOMER[c]","G6622-MONOMER[i]","EG11916-MONOMER[c]","G6644-MONOMER[c]","IMP-DEHYDROG-MONOMER[c]","EG11438-MONOMER[c]","KDO-8PSYNTH-MONOMER[c]","FOLC-MONOMER[c]","G6527-MONOMER[p]","EG11100-MONOMER[c]","G7184-MONOMER[c]","G6757-MONOMER[c]","ARTP-MONOMER[i]","EG11537-MONOMER[c]","EG11110-MONOMER[m]","GPT-MONOMER[c]","MANNPDEHYDROG-MONOMER[c]","AROP-MONOMER[i]","EG11288-MONOMER[c]","EG11676-MONOMER[c]","NUOH-MONOMER[m]","EG10596-MONOMER[c]","UDPNACETYLGLUCOSAMACYLTRANS-MONOMER[c]","BTUE-MONOMER[p]","EG11183-MONOMER[i]","L-GLN-FRUCT-6-P-AMINOTRANS-MONOMER[c]","EG11534-MONOMER[c]","EG11118-MONOMER[c]","ILES-MONOMER[c]","USHA-MONOMER[p]","EG11850-MONOMER[c]","EG10996-MONOMER[c]","EG11344-MONOMER[c]","GLYOXI-MONOMER[c]","EG10215-MONOMER[c]","EG12371-MONOMER[o]","EG10335-MONOMER[c]","EG10370-MONOMER[c]","EG10869-MONOMER[c]","PDXA-MONOMER[c]","G6539-MONOMER[c]","QUINOPRIBOTRANS-MONOMER[c]","EG11653-MONOMER[c]","PD00194[c]","EG11507-MONOMER[c]","G7298-MONOMER[m]","G7656-MONOMER[c]","CYSP-MONOMER[p]","NAD-SYNTH-MONOMER[c]","FERREDOXIN-MONOMER[c]","EG11338-MONOMER[c]","G7200-MONOMER[c]","EG10760-MONOMER[p]","G7697-MONOMER[c]","G6904-MONOMER[e]","EG11134-MONOMER[c]","G6320-MONOMER[m]","UDPNACETYLGLUCOSAMENOLPYRTRANS-MONOMER[c]","POTF-MONOMER[p]","EG10909-MONOMER[c]","EG10684-MONOMER[o]","CYOA-MONOMER[i]","THREDEHYDSYN-MONOMER[c]","GLUCOSE-1-PHOSPHAT-MONOMER[p]","CYCA-MONOMER[i]","EG11202-MONOMER[c]","EG11447-MONOMER[c]","EG10437-MONOMER[c]","CYCLASE-MONOMER[c]","EG12130-MONOMER[c]","PGK[c]","ATPC-MONOMER[m]","ADENODEAMIN-MONOMER[c]","G6887-MONOMER[c]","EG11059-MONOMER[c]","EG10905-MONOMER[c]","EG11293-MONOMER[p]","G7574-MONOMER[p]","EG11239-MONOMER[c]","GALPMUT-MONOMER[c]","PHES-MONOMER[c]","GMP-SYN-MONOMER[c]","CITSYN-MONOMER[c]","THREODEHYD-MONOMER[c]","EG11733-MONOMER[c]","EG12879-MONOMER[c]","EG11137-MONOMER[c]","G6763-MONOMER[p]","EG11128-MONOMER[c]","EG12295-MONOMER[c]","TRANSKETOII-MONOMER[c]","GALACTURIDYLYLTRANS-MONOMER[c]","METQ-MONOMER[m]","UDK-MONOMER[c]","EG12365-MONOMER[c]","E1O-MONOMER[c]","DIHYDROOROTOX-MONOMER[c]","G6731-MONOMER[c]","GLYC3PDEHYDROGBIOSYN-MONOMER[c]","SARCOX-MONOMER[c]","EG10912-MONOMER[c]","EG10671-MONOMER[o]","DIHYDROFOLATEREDUCT-MONOMER[c]","G7808-MONOMER[i]","ANTHRANSYNCOMPI-MONO ...

# %% [markdown]
# # Wisniewski Validation Data Comparisons

# %% [markdown]
# Plot #3: Compare the Wisniewski Validation Protein Counts for the CLNE and CLClim0NE models

# %%
# Create scatter plot of Schmidt Validation Protein Counts vs CLNE and CLClimNE Counts
def add_scatter_and_trendline(fig, df, name):
    x = df["Log10 Validation Wisniewski Counts"]
    y = df["Log10 Simulated Wisniewski Counts"]
    hovertext = df["Monomer ID"]

    # Add scatter trace
    fig.add_trace(go.Scatter(x=x, y=y, hovertext=hovertext, mode='markers', name=name))

    # Compute trendline
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)
    trendline_y = p(x)

    # Add trendline trace
    fig.add_trace(go.Scatter(x=x, y=trendline_y, mode='lines', name=f'{name} Trendline: {p}'))

# Create figure
fig = go.Figure()

# Add scatter plots and trendlines for each dataset
add_scatter_and_trendline(fig, VW_log_CLNE, 'CLNE vs Wisniewski')
add_scatter_and_trendline(fig, VW_log_CLClimNE, (current_sequence +' vs Wisniewski'))

# Update layout
fig.update_traces(marker_size=3)
fig.update_layout(
    title=f"Wisniewski Validation Protein Counts vs CLNE and {current_sequence}",
    xaxis_title="log10(Wisniewski Validation Protein Counts)",
    yaxis_title=f"log10(CLNE, {current_sequence})",
    autosize=False,
    width=900,
    height=600
)

# add a y=x line
fig.add_trace(go.Scatter(x=[0, 6], y=[0, 6], mode="lines",
        line=go.scatter.Line(color="black", dash="dash"), opacity=0.2,
        name="y=x"));
# Show figure
fig.show()
# Out:
# <div>                            <div id="ca3c3631-8747-4226-b322-8e664cca997a" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca3c3631-8747-4226-b322-8e664cca997a")) {                    Plotly.newPlot(                        "ca3c3631-8747-4226-b322-8e664cca997a",                        [{"hovertext":["EG10339-MONOMER[c]","EG11008-MONOMER[p]","G7189-MONOMER[i]","G7416-MONOMER[c]","EG10923-MONOMER[c]","GLNH-MONOMER[p]","PANTEPADENYLYLTRAN-MONOMER[c]","EG11007-MONOMER[i]","G7875-MONOMER[i]","PD00339[c]","EG12220-MONOMER[i]","G6990-MONOMER[o]","EG12861-MONOMER[c]","G6383-MONOMER[c]","G7612-MONOMER[i]","G7680-MONOMER[c]","G7597-MONOMER[c]","THRESYN-MONOMER[c]","G7258-MONOMER[i]","EG10864-MONOMER[c]","EG10242-MONOMER[c]","EG10015-MONOMER[i]","ACNEULY-MONOMER[c]","PEPSYNTH-MONOMER[c]","7-ALPHA-HYDROXYSTEROID-DEH-MONOMER[c]","SUCCCOASYN-BETA[c]","PD00196[c]","DIOHBUTANONEPSYN-MONOMER[c]","BASR-MONOMER[c]","EG10748-MONOMER[m]","ATPE-MONOMER[m]","TRE6PHYDRO-MONOMER[c]","G7525-MONOMER[c]","GLYCDEH-MONOMER[c]","G7925-MONOMER[c]","EG10915-MONOMER[c]","G6924-MONOMER[c]","EG10977-MONOMER[c]","BARA-MONOMER[i]","BIOTINLIG-MONOMER[c]","NUOA-MONOMER[m]","EG10862-MONOMER[c]","G6560-MONOMER[c]","G6428-MONOMER[c]","G7039-MONOMER[p]","EG11929-MONOMER[c]","G7489-MONOMER[c]","EG12105-MONOMER[c]","CITRYLY-MONOMER[c]","MONOMER0-4521[c]","G7311-MONOMER[m]","G6267-MONOMER[i]","G7137-MONOMER[c]","FLGH-FLAGELLAR-L-RING[j]","G6845-MONOMER[i]","HISTPHOSTRANS-MONOMER[c]","CYDB-MONOMER[m]","EG12158-MONOMER[c]","EG11535-MONOMER[c]","G6323-MONOMER[i]","VALINE-PYRUVATE-AMINOTRANSFER-MONOMER[c]","EG12851-MONOMER[c]","EG11203-MONOMER[c]","G6255-MONOMER[i]","YADG-MONOMER[i]","EG11336-MONOMER[p]","G7035-MONOMER[c]","NUOK-MONOMER[m]","EG11702-MONOMER[c]","EG11779-MONOMER[c]","EG10272-MONOMER[i]","G7492-MONOMER[c]","G7606-MONOMER[m]","EG11917-MONOMER[c]","GLYCPDIESTER-CYTO-MONOMER[c]","EG12233-MONOMER[c]","EG12712-MONOMER[c]","EG12193-MONOMER[c]","FLGG-FLAGELLAR-MOTOR-ROD-PROTEIN[o]","EG10927-MONOMER[c]","EG11906-MONOMER[c]","YEJF-MONOMER[i]","EG12352-MONOMER[c]","XYLULOKIN-MONOMER[c]","AICARTRANSIMPCYCLO-CPLX[c]","G7528-MONOMER[i]","MALF-MONOMER[m]","GLTS-MONOMER[i]","CARBPSYN-LARGE[c]","CARBOXYL-TRANSFERASE-ALPHA-MONOMER[c]","G7532-MONOMER[c]","G7055-MONOMER[c]","EG11519-MONOMER[c]","EG11529-MONOMER[i]","EG12188-MONOMER[c]","PITA-MONOMER[i]","EG10914-MONOMER[c]","G7885-MONOMER[c]","G7420-MONOMER[c]","LIVG-MONOMER[m]","EG12443-MONOMER[c]","EG11088-MONOMER[c]","MANNPISOM-MONOMER[c]","RIBAZOLEPHOSPHAT-MONOMER[c]","G6622-MONOMER[i]","G6849-MONOMER[c]","EG11916-MONOMER[c]","G6500-MONOMER[c]","NIKD-MONOMER[m]","EG11852-MONOMER[c]","EG11413-MONOMER[c]","EG10955-MONOMER[c]","IMP-DEHYDROG-MONOMER[c]","EG11438-MONOMER[c]","KDO-8PSYNTH-MONOMER[c]","FOLC-MONOMER[c]","G7946-MONOMER[i]","EG12855-MONOMER[c]","YBAL-MONOMER[i]","EG11494-MONOMER[i]","G6258-MONOMER[c]","EG10040-MONOMER[p]","G6527-MONOMER[p]","G7056-MONOMER[m]","RBSA-MONOMER[m]","EG11100-MONOMER[c]","G7184-MONOMER[c]","G6278-MONOMER[c]","G7355-MONOMER[i]","G7847-MONOMER[c]","EG12386-MONOMER[c]","G6757-MONOMER[c]","ARTP-MONOMER[i]","EG11537-MONOMER[c]","EG11110-MONOMER[m]","GPT-MONOMER[c]","EG11082-MONOMER[c]","G6672-MONOMER[c]","PDXK-MONOMER[c]","MANNPDEHYDROG-MONOMER[c]","ARGDECARBOXDEG-MONOMER[c]","EG10204-MONOMER[c]","EG11676-MONOMER[c]","EG11288-MONOMER[c]","OPPC-MONOMER[i]","POTC-MONOMER[i]","OCTAPRENYL-METHYL-METHOXY-BENZOQ-OH-MON[c]","NUOH-MONOMER[m]","EG10596-MONOMER[c]","UDPNACETYLGLUCOSAMACYLTRANS-MONOMER[c]","BTUE-MONOMER[p]","G6870-MONOMER[i]","EG10122-MONOMER[c]","EG11183-MONOMER[i]","L-GLN-FRUCT-6-P-AMINOTRANS-MONOMER[c]","EG11534-MONOMER[c]","EG11118-MONOMER[c]","B2075-MONOMER[i]","ILES-MONOMER[c]","BTUD-MONOMER[m]","G7657-MONOMER[c]","USHA-MONOMER[p]","EG11850-MONOM ...

# %% [markdown]
# Plot #4: Compare the Wisniewski Validation Protein Counts for the CLNE and CLClim0NE models (but filter values below log10(2))

# %%
# Create scatter plot of Schmidt Validation Protein Counts vs CLNE and CLClimNE Counts
def add_scatter_and_trendline(fig, df, name):
    x = df["Log10 Validation Wisniewski Counts"]
    y = df["Log10 Simulated Wisniewski Counts"]
    hovertext = df["Monomer ID"]

    # Add scatter trace
    fig.add_trace(go.Scatter(x=x, y=y, hovertext=hovertext, mode='markers', name=name))

    # Compute trendline
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)
    trendline_y = p(x)

    # Add trendline trace
    fig.add_trace(go.Scatter(x=x, y=trendline_y, mode='lines', name=f'{name} Trendline: {p}'))

# Create figure
fig = go.Figure()

# Add scatter plots and trendlines for each dataset
# filter out any counts below log10(2):
VW_log_CLNE = VW_log_CLNE[(VW_log_CLNE["Log10 Validation Wisniewski Counts"] > 2) & (VW_log_CLNE["Log10 Simulated Wisniewski Counts"] > 2)]
VW_log_CLClimNE = VW_log_CLClimNE[(VW_log_CLClimNE["Log10 Validation Wisniewski Counts"] > 2) & (VW_log_CLClimNE["Log10 Simulated Wisniewski Counts"] > 2)]
add_scatter_and_trendline(fig, VW_log_CLNE, 'CLNE vs Wisniewski')
add_scatter_and_trendline(fig, VW_log_CLClimNE, (current_sequence +' vs Wisniewski'))

# Update layout
fig.update_traces(marker_size=3)
fig.update_layout(
    title=f"Wisniewski Validation Protein Counts vs CLNE and {current_sequence}",
    xaxis_title="log10(Wisniewski Validation Protein Counts)",
    yaxis_title=f"log10(CLNE, {current_sequence})",
    autosize=False,
    width=900,
    height=600
)

# add a y=x line
fig.add_trace(go.Scatter(x=[2, 6], y=[2, 6], mode="lines",
        line=go.scatter.Line(color="black", dash="dash"), opacity=0.2,
        name="y=x"));
# Show figure
fig.show()
# Out:
# <div>                            <div id="52155203-3edb-4d0f-ace8-8210dae45e68" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52155203-3edb-4d0f-ace8-8210dae45e68")) {                    Plotly.newPlot(                        "52155203-3edb-4d0f-ace8-8210dae45e68",                        [{"hovertext":["EG11008-MONOMER[p]","GLNH-MONOMER[p]","PANTEPADENYLYLTRAN-MONOMER[c]","EG12861-MONOMER[c]","G7612-MONOMER[i]","THRESYN-MONOMER[c]","G7258-MONOMER[i]","EG10864-MONOMER[c]","EG10242-MONOMER[c]","EG10015-MONOMER[i]","ACNEULY-MONOMER[c]","PEPSYNTH-MONOMER[c]","7-ALPHA-HYDROXYSTEROID-DEH-MONOMER[c]","SUCCCOASYN-BETA[c]","PD00196[c]","DIOHBUTANONEPSYN-MONOMER[c]","ATPE-MONOMER[m]","EG10915-MONOMER[c]","EG10977-MONOMER[c]","NUOA-MONOMER[m]","G7039-MONOMER[p]","G7311-MONOMER[m]","FLGH-FLAGELLAR-L-RING[j]","EG12158-MONOMER[c]","EG12851-MONOMER[c]","EG11203-MONOMER[c]","NUOK-MONOMER[m]","EG11779-MONOMER[c]","EG12712-MONOMER[c]","EG12193-MONOMER[c]","EG12352-MONOMER[c]","CARBOXYL-TRANSFERASE-ALPHA-MONOMER[c]","G7532-MONOMER[c]","G7055-MONOMER[c]","EG10914-MONOMER[c]","G7885-MONOMER[c]","EG12443-MONOMER[c]","EG11088-MONOMER[c]","MANNPISOM-MONOMER[c]","IMP-DEHYDROG-MONOMER[c]","KDO-8PSYNTH-MONOMER[c]","EG12855-MONOMER[c]","G6527-MONOMER[p]","EG11100-MONOMER[c]","G7184-MONOMER[c]","G6757-MONOMER[c]","EG11537-MONOMER[c]","EG11110-MONOMER[m]","GPT-MONOMER[c]","PDXK-MONOMER[c]","MANNPDEHYDROG-MONOMER[c]","EG11676-MONOMER[c]","UDPNACETYLGLUCOSAMACYLTRANS-MONOMER[c]","L-GLN-FRUCT-6-P-AMINOTRANS-MONOMER[c]","EG11534-MONOMER[c]","ILES-MONOMER[c]","EG11850-MONOMER[c]","EG10996-MONOMER[c]","EG11344-MONOMER[c]","EG11315-MONOMER[c]","GLYOXI-MONOMER[c]","EG10215-MONOMER[c]","EG10335-MONOMER[c]","EG10370-MONOMER[c]","EG10869-MONOMER[c]","QUINOPRIBOTRANS-MONOMER[c]","PD00194[c]","EG11507-MONOMER[c]","G7298-MONOMER[m]","G7656-MONOMER[c]","NAD-SYNTH-MONOMER[c]","EG11134-MONOMER[c]","UDPNACETYLGLUCOSAMENOLPYRTRANS-MONOMER[c]","G7662-MONOMER[c]","EG10909-MONOMER[c]","EG10684-MONOMER[o]","CYOA-MONOMER[i]","GLUCOSE-1-PHOSPHAT-MONOMER[p]","EG11447-MONOMER[c]","EG10375-MONOMER[c]","EG10437-MONOMER[c]","CYCLASE-MONOMER[c]","EG12130-MONOMER[c]","PGK[c]","ATPC-MONOMER[m]","ADENODEAMIN-MONOMER[c]","MONOMER0-1981[c]","G6887-MONOMER[c]","EG11059-MONOMER[c]","EG10905-MONOMER[c]","EG11293-MONOMER[p]","MONOMER0-4519[c]","PHES-MONOMER[c]","GMP-SYN-MONOMER[c]","G6873-MONOMER[c]","CITSYN-MONOMER[c]","THREODEHYD-MONOMER[c]","EG12879-MONOMER[c]","EG11137-MONOMER[c]","EG11147-MONOMER[c]","GLNP-MONOMER[i]","EG12295-MONOMER[c]","GALACTURIDYLYLTRANS-MONOMER[c]","DIACYLGLYKIN-MONOMER[i]","METQ-MONOMER[m]","UDK-MONOMER[c]","E1O-MONOMER[c]","DIHYDROOROTOX-MONOMER[c]","G6731-MONOMER[c]","GLYC3PDEHYDROGBIOSYN-MONOMER[c]","SARCOX-MONOMER[c]","EG10912-MONOMER[c]","EG10671-MONOMER[o]","DIHYDROFOLATEREDUCT-MONOMER[c]","G7808-MONOMER[i]","CPM-KDOSYNTH-MONOMER[c]","NAPHTHOATE-SYN-MONOMER[c]","G7090-MONOMER[m]","POTD-MONOMER[p]","G6474-MONOMER[p]","G6158-MONOMER[i]","EG11345-MONOMER[i]","G7452-MONOMER[c]","ASNSYNA-MONOMER[c]","EG11517-MONOMER[c]","EG12454-MONOMER[c]","G7743-MONOMER[c]","G6423-MONOMER[c]","EG11011-MONOMER[i]","EG11884-MONOMER[c]","EG12271-MONOMER[i]","EG11508-MONOMER[c]","EG11091-MONOMER[c]","EG11252-MONOMER[c]","EG12310-MONOMER[c]","G6465-MONOMER[p]","ACONITASE-MONOMER[c]","EG11182-MONOMER[c]","EG10884-MONOMER[c]","EG10885-MONOMER[c]","FORMYLTHFDEFORMYL-MONOMER[c]","FABZ-MONOMER[c]","G6499-MONOMER[c]","GLYCOPHOSPHORYL-MONOMER[c]","EG10978-MONOMER[c]","FUMC-MONOMER[c]","EG10761-MONOMER[c]","ALDOSE1EPIM-MONOMER[c]","LTAA-MONOMER[c]","G7003-MONOMER[c]","ARGSUCCINSYN-MONOMER[c]","MODA-MONOMER[p]","EG11259-MONOMER[c]","EG11246-MONOMER[c]","EG11511-MONOMER[c]","EG10918-MONOMER[c]","FLIM-FLAGELLAR-C-RING-SWITCH[i]","OHMETHYLBILANESYN-MONOMER[c]" ...

# %% [markdown]
# # Plot of the proteases in the ClimNE model

# %%
# FUNCTIONS

# get the gene IDs for each monomer IDs:
def get_gene_ids_for_monomer_ids():
    # code adapted from convert_to_flat.py
    import io
    from wholecell.io import tsv
    from wholecell.utils.filepath import ROOT_PATH
    RNAS_FILE = os.path.join(ROOT_PATH, 'reconstruction', 'ecoli', 'flat', 'rnas.tsv')
    with io.open(RNAS_FILE, 'rb') as f:
        reader = tsv.reader(f, delimiter='\t')
        headers = next(reader)
        while headers[0].startswith('#'):
            headers = next(reader)

        gene_id_index = headers.index('gene_id')
        protein_id_index = headers.index('monomer_ids')
        monomer_ids_to_gene_ids = {}
        for line in reader:
            gene_id = line[gene_id_index]
            protein_id = list(line[protein_id_index][2:-2].split('", "'))[0]
            monomer_ids_to_gene_ids[protein_id] = gene_id

        return monomer_ids_to_gene_ids
    
def get_gene_symbols_for_monomer_ids():
    # code adapted from convert_to_flat.py
    import io
    from wholecell.io import tsv
    from wholecell.utils.filepath import ROOT_PATH
    RNAS_FILE = os.path.join(ROOT_PATH, 'reconstruction', 'ecoli', 'flat', 'rnas.tsv')
    with io.open(RNAS_FILE, 'rb') as f:
        reader = tsv.reader(f, delimiter='\t')
        headers = next(reader)
        while headers[0].startswith('#'):
            headers = next(reader)

        gene_symbol_index = headers.index('common_name')
        protein_id_index = headers.index('monomer_ids')
        monomer_ids_to_gene_symbols = {}
        for line in reader:
            gene_symbol = line[gene_symbol_index]
            protein_id = list(line[protein_id_index][2:-2].split('", "'))[0]
            monomer_ids_to_gene_symbols[protein_id] = gene_symbol

        return monomer_ids_to_gene_symbols
    
    
# convert gene IDs to monomer IDs:
def get_monomer_ids_for_gene_ids():
    # code adapted from convert_to_flat.py
    import io
    from wholecell.io import tsv
    from wholecell.utils.filepath import ROOT_PATH
    RNAS_FILE = os.path.join(ROOT_PATH, 'reconstruction', 'ecoli', 'flat', 'rnas.tsv')
    with io.open(RNAS_FILE, 'rb') as f:
        reader = tsv.reader(f, delimiter='\t')
        headers = next(reader)
        while headers[0].startswith('#'):
            headers = next(reader)

        gene_id_index = headers.index('gene_id')
        protein_id_index = headers.index('monomer_ids')
        gene_ids_to_monomer_ids = {}
        for line in reader:
            gene_id = line[gene_id_index]
            protein_id = list(line[protein_id_index][2:-2].split('", "'))[0]
            gene_ids_to_monomer_ids[gene_id] = protein_id

        return gene_ids_to_monomer_ids
    
    
# recall the genes defined as "essential" in the model, and return them as a list of gene names:
def get_essential_genes():
    # code adapted from convert_to_flat.py
    import io
    from wholecell.io import tsv
    from wholecell.utils.filepath import ROOT_PATH
    GENES_FILE = os.path.join(ROOT_PATH, 'validation', 'ecoli', 'flat', 'essential_genes.tsv')
    with io.open(GENES_FILE, 'rb') as f:
        reader = tsv.reader(f, delimiter='\t')
        headers = next(reader)
        while headers[0].startswith('#'):
            headers = next(reader)

        gene_id_index = headers.index('FrameID')
        essential_genes = []
        for line in reader:
            essential_gene = line[gene_id_index]
            essential_genes.append(essential_gene)

        return essential_genes
	
	
# convert the data from the ParCa translation.py raw HL saves: 
def convert_HL_data(dataframe):
    name_s = 'rate constant (s^1)' # name in seconds
    name_m = 'half life (min)' # name in mins
    dataframe.rename(columns={'Rate Constant': name_s}, inplace=True)
    dataframe[name_m] = dataframe[name_s] * 60 * (1/np.log(2))
    dataframe[name_m] = 1 / dataframe[name_m] # units of mins
    return dataframe


# convert each data source in the saved HL data file folders 
def convert_data_and_add_HL_source(dataframe, HL_source):
    name_s = HL_source + ' rate constant (s^1)' # name in seconds
    name_m = HL_source + ' half life (min)' # name in mins
    dataframe.rename(columns={'Rate Constant': name_s}, inplace=True)
    dataframe[name_m] = dataframe[name_s] * 60 * (1/np.log(2))
    dataframe[name_m] = 1 / dataframe[name_m] # units of mins
    return dataframe

# %%
# load in the protease-substrate assignment datatable: 
protease_data = pd.read_excel('~/wcEcoli/models/ecoli/analysis/local_notebooks/C_limited_PDR_analyses_with_published_paper_data/supplementary_data/Gupta_et_al_2024_ST2_protease_assignment_data.xlsx')

# determine if any of the proteins assigned to a protease are considered an essential gene in the model: 
essential_substrate_gene_symbols = []
for gene in get_essential_genes():
    if get_gene_symbols_for_monomer_ids()[get_monomer_ids_for_gene_ids()[gene]] in protease_data['Gene name'].values:
        essential_substrate_gene_symbols.append(get_gene_symbols_for_monomer_ids()[get_monomer_ids_for_gene_ids()[gene]])
        
print("There are " + str(len(protease_data['Gene name'].values)) + " proteins assigned to a protease in the Gupta et al., 2024 data.")
print("Essential Genes in Model that are Assigned to a Protease (" +str(len(essential_substrate_gene_symbols))+"): ", essential_substrate_gene_symbols)
# Out:
# There are 308 proteins assigned to a protease in the Gupta et al., 2024 data.
# Essential Genes in Model that are Assigned to a Protease (57):  ['bioB', 'ilvE', 'argA', 'aroE', 'cysH', 'cysI', 'cysJ', 'cysN', 'leuA', 'leuC', 'leuD', 'lysA', 'thrA', 'trpB', 'tyrA', 'iscS', 'nadA', 'nadB', 'metR', 'ispH', 'ftsI', 'ftsQ', 'ftsZ', 'lpxC', 'erpA', 'frr', 'dxr', 'ispU', 'dnaE', 'thiL', 'dnaX', 'ftsK', 'rpsA', 'mukB', 'acpP', 'minE', 'hemA', 'folE', 'ligA', 'dapA', 'ispG', 'era', 'ffh', 'metK', 'parE', 'ribB', 'obgE', 'def', 'rplX', 'dnaA', 'birA', 'rpoB', 'rpoC', 'ubiA', 'lexA', 'dnaB', 'dnaC']

# %%
VS_log_CLClimNE
# Out:
#                    Monomer ID  Log10 Simulated Schmidt Counts
# 0            G6814-MONOMER[c]                        2.430598  \
# 1     ALDHDEHYDROG-MONOMER[c]                        2.069846
# 2          EG11838-MONOMER[c]                        1.552474
# 3          EG11195-MONOMER[c]                        2.963099
# 4            G7651-MONOMER[c]                        2.429409
# ...                       ...                             ...
# 2136          G369-MONOMER[c]                        3.558480
# 2137       EG11802-MONOMER[c]                        0.731940
# 2138          NUOK-MONOMER[m]                        1.931831
# 2139       EG10877-MONOMER[c]                        4.344847
# 2140           PROTEIN-PII[c]                        3.236839
#
#       Log10 Validation Schmidt Counts
# 0                            1.986772
# 1                            2.068186
# 2                            0.845098
# 3                            2.709270
# 4                            0.845098
# ...                               ...
# 2136                         1.230449
# 2137                         1.204120
# 2138                         2.361728
# 2139                         4.520038
# 2140                         3.106191
#
# [2141 rows x 3 columns]

# %%
# determine which monomer IDs are protein substrates of the proteases in the CLClim0NE model:
monomer_ids = VS_log_CLClimNE['Monomer ID']
monomer_ids = monomer_ids.str.slice(0, -3)

CLClim0NE_protease_substrate_gene_symbols = []
CLClim0NE_protease_substrate_monomer_ids = []
for monomer_id in monomer_ids:
	monomer = monomer_id
	gene_symbol = get_gene_symbols_for_monomer_ids()[monomer]
	if gene_symbol in protease_data['Gene name'].values:
		CLClim0NE_protease_substrate_gene_symbols.append(gene_symbol)
		CLClim0NE_protease_substrate_monomer_ids.append(monomer)
        
print("Total Protease Substrates in CLClimNE (" +str(len(CLClim0NE_protease_substrate_gene_symbols))+"): ", Clim0_protease_substrate_gene_symbols)

VS_log_CLClimNE['gene symbol'] = VS_log_CLClimNE['Monomer ID'].apply(lambda x: get_gene_symbols_for_monomer_ids()[x[:-3]]) # this is to add to the hovertext
# if a monomer in CLClim0NE_protease_substrate_gene_symbols is found in monomer_ids, remove them from Clim0_data and add it to a new dataframe: 
CLClim0NE_protease_substrate_idxs = monomer_ids.isin(CLClim0NE_protease_substrate_monomer_ids)
CLClim0NE_protease_substrates = VS_log_CLClimNE[CLClim0NE_protease_substrate_idxs].copy()
CLClim0NE_protease_substrates['HL Source'] = f"{current_sequence} (protease substrate)"
CLClim0NE_VS_log_data_remaining = VS_log_CLClimNE[~CLClim0NE_protease_substrate_idxs].copy()
# Out:
# Total Protease Substrates in CLClimNE (236):  ['leuA', 'ubiA', 'ackA', 'acnB', 'fadE', 'glpD', 'cysJ', 'uxaA', 'astA', 'aroD', 'aroE', 'aroG', 'aroK', 'aroL', 'asnA', 'aspA', 'thrA', 'cysI', 'bioB', 'birA', 'ilvE', 'chbB', 'cfa', 'tyrA', 'ubiC', 'cycA', 'cysD', 'cysN', 'dadA', 'lysA', 'dapA', 'nfsB', 'ribB', 'cobT', 'dxr', 'yaaA', 'bisC', 'clpA', 'clpX', 'dedA', 'dedD', 'dksA', 'dnaB', 'dnaC', 'dnaE', 'dnaK', 'dnaQ', 'era', 'ffh', 'frr', 'ftsI', 'ftsZ', 'ispG', 'mnmG', 'greA', 'helD', 'hflX', 'hmp', 'hsdM', 'hypE', 'ligA', 'mazG', 'minE', 'mukB', 'mutS', 'nfo', 'parC', 'parE', 'pcnB', 'priC', 'pspA', 'recA', 'recD', 'recF', 'recJ', 'rhlB', 'rplX', 'rpsA', 'ruvC', 'sbcC', 'selD', 'prlF', 'srmB', 'tonB', 'topB', 'uvrB', 'uvrD', 'ispH', 'sbcD', 'ybaB', 'relE', 'yebC', 'yecA', 'uvrY', 'yibA', 'yidA', 'mioC', 'ybhA', 'rlmD', 'mazF', 'radA', 'rng', 'lipA', 'dinG', 'ahpC', 'ahpF', 'ychF', 'yjgA', 'dps', 'def', 'yigI', 'ycgB', 'ibpA', 'greB', 'grcA', 'yihD', 'yihI', 'yiiQ', 'rsuA', 'radD', 'ccmH', 'ydcF', 'hscA', 'hscB', 'iscA', 'cspE', 'cspC', 'bcsG', 'yiaU', 'ycfH', 'yfhH', 'hrpB', 'erpA', 'ppiC', 'rlmN', 'iaaA', 'ydiF', 'rarA', 'nudL', 'proQ', 'ybcJ', 'acpP', 'fbp', 'fadB', 'fucI', 'intF', 'prpR', 'rnk', 'ybeZ', 'miaB', 'ybgI', 'clsB', 'ybiU', 'ybjI', 'ftsK', 'ycaR', 'comR', 'rluE', 'mpaA', 'ydbK', 'azoR', 'ydcI', 'dosP', 'ydeP', 'sad', 'ydfZ', 'ynfC', 'nemA', 'ydhQ', 'ydhS', 'sufS', 'sufD', 'sufB', 'yeaH', 'yegU', 'yegW', 'yfaY', 'arnA', 'arnD', 'elaA', 'alaA', 'yfcL', 'sixA', 'yfcZ', 'alaC', 'murQ', 'ypfH', 'bepA', 'iscU', 'iscS', 'iscR', 'kbp', 'ygaP', 'csdA', 'guaD', 'yggX', 'patA', 'obgE', 'nanR', 'yheO', 'yhgF', 'nfuA', 'tatB', 'epmB', 'fklB', 'tabA', 'yjjU', 'gabT', 'gcvT', 'gdhA', 'garK', 'glnD', 'gph', 'folE', 'folX', 'metH', 'aceA', 'nadB', 'lldD', 'ilvB', 'leuC', 'leuD', 'sdaA', 'dkgB', 'dnaX', 'argA', 'amiB', 'narP', 'cysH', 'fnr', 'lexA', 'oxyR', 'fhlA', 'exuR', 'dnaA', 'metR', 'ppx', 'putA', 'pflB', 'nadA', 'trxC', 'nrdD', 'rpoB', 'rpoC', 'rpoD', 'rpoS', 'metK', 'secG', 'astB', 'astD', 'astE', 'astC', 'thiL', 'thiC', 'thiE', 'thiF', 'thiG', 'thiH', 'trxB', 'thiM', 'tktA', 'otsA', 'trpB', 'lpxC', 'wecB', 'ugd', 'uhpA', 'hemE', 'avtA', 'yheS', 'zntA', 'gsiA', 'znuC']

# %%
import numpy as np
import plotly.graph_objs as go

# Create scatter plot of Schmidt Validation Protein Counts vs CLNE and CLClimNE Counts
def add_scatter_and_trendline(fig, df, name, is_protease_substrate=False):
    x = df["Log10 Validation Schmidt Counts"]
    y = df["Log10 Simulated Schmidt Counts"]
    hovertext = df["gene symbol"]
	
    # Properly indented if statement
    if is_protease_substrate == True:
        fig.add_trace(go.Scatter(x=x, y=y, hovertext=hovertext, mode='markers', 
                                  marker_size=7, marker=dict(color="orange", symbol='star'), 
                                  name=name))
    else: 
        fig.add_trace(go.Scatter(x=x, y=y, hovertext=hovertext, mode='markers', marker_size=4,
                                 marker=dict(color="lightseagreen"),  name=name))
		
        # Compute trendline
        z = np.polyfit(x, y, 1)
        p = np.poly1d(z)
        trendline_y = p(x)
    
        # Add trendline trace
        fig.add_trace(go.Scatter(x=x, y=trendline_y, mode='lines', line=dict(color="salmon"), name=f'{name} Trendline: {p}'))

# Create figure
fig = go.Figure()

# Add scatter plots and trendlines for each dataset
add_scatter_and_trendline(fig, CLClim0NE_VS_log_data_remaining, (current_sequence + ' vs Schmidt'))
add_scatter_and_trendline(fig, CLClim0NE_protease_substrates, (current_sequence + '(protease substrates) vs Schmidt'), True)

# Update layout
fig.update_layout(
    title=f"Schmidt Validation Protein Counts vs {current_sequence}",
    xaxis_title="log10(Schmidt Validation Protein Counts)",
    yaxis_title=f"log10({current_sequence})",
    autosize=False,
    width=1200,
    height=1000
)

# Add a y=x line
fig.add_trace(go.Scatter(x=[0, 6], y=[0, 6], mode="lines",
        line=dict(color="black", dash="dash"), opacity=0.2,
        name="y=x"))

# Show figure
fig.show()
# Out:
# <div>                            <div id="feb56ca8-1aea-4d44-9996-8b3ed1b31d26" class="plotly-graph-div" style="height:1000px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("feb56ca8-1aea-4d44-9996-8b3ed1b31d26")) {                    Plotly.newPlot(                        "feb56ca8-1aea-4d44-9996-8b3ed1b31d26",                        [{"hovertext":["rspR","puuC","yihL","ubiT","mglB","rpiB","ygaM","ybgA","moaB","yccJ","yeiE","aroH","fhuE","mdtE","yhiN","coaE","oppA","yfgJ","priB","rimP","yrbL","yeaG","yceI","idi","phnP","leuS","rlmE","selA","rsmC","trhO","csrA","raiA","slmA","lptB","malQ","nuoB","hisH","gltL","dcrB","pfkA","purT","yciC","pth","ybgS","hemD","wbbK","glmM","gnd","lptC","livG","entH","tatE","ynfB","ygdI","cysC","rsmB","feaR","hinT","cyoC","carA","dpiA","lysC","seqA","shiA","tatC","glgS","purH","glcB","hisC","nuoE","glgC","fpr","ydfW","umpG","yqjG","dsbB","cmk","sgbH","pyrG","rcnR","aroC","uxuB","atpD","aceE","rpsQ","hybE","narL","malS","ugpB","nemR","yffB","yciN","cysB","fdoH","pyrD","yajI","matP","ybeY","yjhU","yobA","apaH","yqjC","nuoA","argS","cyoA","ubiH","asr","lptE","tdk","gatD","dtd","fldA","relB","yhjG","dppD","pdeA","hda","mraZ","cydB","codB","rppH","murR","kefC","gor","yedF","cydC","fepA","ynaE","feoA","tpx","nudJ","pgl","nusA","dsbA","gstA","hemY","hypB","purN","hybA","galE","ybjL","pntB","rsxC","purM","prpC","paaK","yfgD","fdoI","ybfE","gutQ","gldA","truC","priA","nudE","allR","lsrF","rsxG","mhpD","yhfG","creA","ptsH","gadC","nanY","idnK","ydcJ","mhpR","ybcH","ettA","mdtA","manZ","clpP","potF","folM","rplD","ansB","spoT","malE","soxR","xthA","serS","hdeA","ycgM","ugpQ","glpQ","panD","tsaE","yafN","dapE","zapD","eco","yhbO","oppC","hemC","guaC","dacA","yfdI","truB","artP","yeaK","glnE","aroA","cusB","ptsN","ftnB","rob","proW","hycA","cpdB","yebV","yehS","cspB","uspF","dgcJ","gatZ","rplI","yigB","gltI","fliG","acnA","ldcC","rnb","bioF","mlaD","trmH","fur","gadB","fecR","hyaA","hprS","degP","hcxA","rpsR","cutA","nuoM","cpxR","infA","hflK","dgcM","ubiX","bcp","paaB","cspD","arcB","yfhM","xseB","hemX","accA","fabB","zapA","nuoH","pnuC","rpmJ","kbl","ispD","rlmJ","nanK","tolQ","paeA","ygdG","lnt","gntR","yjiM","yliI","thyA","cusF","hisI","ushA","cysE","livM","yafC","cmoA","sufC","pepA","pabA","ydiH","hycE","glf","yciB","garD","sapD","yfcF","ybbO","yjjA","ygiN","uspC","ybbA","nikA","waaA","igaA","minD","metF","cmoB","zur","cdd","garR","tadA","fliF","hrpA","yjeI","iadA","yajO","gltD","xylR","ymdB","ghrA","osmE","yffS","fadH","baeS","yicH","yjhH","ycjG","ykgE","frlB","ulaR","nagK","rmf","nikR","yafV","yigL","trpS","mepH","yggT","tcyP","ydeN","tmaR","hicB","rcsD","vsr","fucU","pfkB","ptrB","rfbD","ldcA","uspE","opgH","znuA","aceF","yejG","speC","rlmH","rpsF","gstB","rimO","glaR","hsdS","emrA","lsrA","yghA","yhcB","acpH","nlpI","kdsC","ybfF","ybbP","moeB","maeA","spy","ndh","yniA","rpsD","rnhB","ribD","pabB","nusB","yejL","nhaB","exbB","yhaJ","zinT","yegP","pstS","phoP","mltB","tldD","pldA","rimI","yagH","yqcA","apt","yddH","ycdX","glnL","hslR","thrP","rplM","rpsS","artJ","glpB","ldtD","rluB","ttcA","hha","nagA","pncC","nupC","ubiB","tdh","xylE","yhhX","cas1","focA","fabZ","ygfF","fhuD","livJ","yaeQ","menB","glyS","cytR","yedK","yeaO","srkA","pxpA","yieP","bglX","murE","rnhA","ruvA","hflD","hisJ","yejK","aroM","wbbJ","yhbW","psiF","rph","ompW","ybaK","rsfS","nuoN","speB","nfrA","asnC","nanE","phoQ","mutM","ftsA","dosC","truD","argG","arcA","fadL","mak","yjdI","oppB","lpp","malT","dcyD","sgcQ","slp","torR","argD","yjbB","ptrA","ybgC","lapA","prpB","copA","yhjJ","ddlB","queE","uhpT","preT","fliA","cheY","guaA","yedP","yfcG","leuB","ileS","rraB","yihU","hemG","argB","hfq","fabY","hisQ","actS","menI","nfeR","tauD","mdaB","ygiC","rapZ","rnt","yajQ","rcsF","yhjE","ggt","nudI","yeaR","yehX","mtlA","pta","ompR","pntA","rsd","mur ...
